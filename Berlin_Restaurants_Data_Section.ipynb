# %% [markdown]
# ## Berlin Restaurants Analysis
#
# We would like to open a restaurant(turkish or italian) in Berlin, therefore we need to decide which area/neighborhood would be the best for it. We want to focus on the center neighborhoods where the most of the touristic attractions are located so that we get more customers at the end.
#
# The steps to be followed:
# - downloading the boroughs and neighborhoods of Berlin by using **Beautiful soup** and **request**
# - getting all latitudes and longitudes of the neighborhoods by using geolocator
# - gathering all the data of the current locations(food places) by making a get request in Forsquare
# - grouping these places according tto their types and locations
# - creating a dataframe in which shows the most common ten types of places for each neighborhood
# - clustering these places
# - making a decision for the best neighborhood to open our restaurant

# %%
import requests 
import pandas as pd 
import numpy as np 
import random 
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim 


from IPython.display import Image 
from IPython.core.display import HTML 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)    

from pandas.io.json import json_normalize



import folium 


print('All the necessary Libraries imported.')
# Out:
# All the necessary Libraries imported.

# %% [markdown]
# #### Importing the boroughs and neigborhoods of Berlin

# %%
URL="https://en.wikipedia.org/wiki/Boroughs_and_neighborhoods_of_Berlin"

# %%
response = requests.get(URL)

web_page = response.text

soup= BeautifulSoup(web_page, "html.parser")

# %%
 def long_lat(address):   
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(f"{address},Berlin")
    latitude = location.latitude
    longitude = location.longitude
    return (latitude, longitude)

# %%
boroughs=[]
neighborhoods=[]
latitude=[]
longitude=[]
data = {"Boroughs":boroughs,"Neighborhoods":neighborhoods,"Latitude":latitude,"Longitude":longitude}
table_1= soup.findAll('table')
all_tr= table_1[-3].findAll("tr")

# %%
for row in all_tr[1:-1]:
    x=row.text.replace("\n",",").split(",")[:-1]
    for i in x[1:]:
        boroughs.append(x[0].strip(" ").split(" ")[0])
        neighborhoods.append(i)
        data["Latitude"].append(long_lat(i)[0])
        data["Longitude"].append(long_lat(i)[1])

# %% [markdown]
# #### creating a dataframe with boroughs, neighborhoods and their latitudes&longitudes

# %%
df=pd.DataFrame(data)
df.drop([50,55,61,83,94],inplace=True)
df
# Out:
#                       Boroughs              Neighborhoods   Latitude  \
# 0   Charlottenburg-Wilmersdorf             Charlottenburg  52.515747
# 1   Charlottenburg-Wilmersdorf        Charlottenburg-Nord  52.540525
# 2   Charlottenburg-Wilmersdorf                  Grunewald  52.487347
# 3   Charlottenburg-Wilmersdorf                   Halensee  52.497226
# 4   Charlottenburg-Wilmersdorf              Schmargendorf  52.478902
# 5   Charlottenburg-Wilmersdorf                    Westend  52.513399
# 6   Charlottenburg-Wilmersdorf                Wilmersdorf  52.487115
# 7     Friedrichshain-Kreuzberg             Friedrichshain  52.512215
# 8     Friedrichshain-Kreuzberg                  Kreuzberg  52.497644
# 9                  Lichtenberg       Alt-Hohenschönhausen  52.550409
# 10                 Lichtenberg                 Falkenberg  52.569300
# 11                 Lichtenberg                  Fennpfuhl  52.528785
# 12                 Lichtenberg            Friedrichsfelde  52.502936
# 13                 Lichtenberg                 Karlshorst  52.484340
# 14                 Lichtenberg                Lichtenberg  52.532161
# 15                 Lichtenberg                    Malchow  52.579867
# 16                 Lichtenberg       Neu-Hohenschönhausen  52.566331
# 17                 Lichtenberg                Rummelsburg  52.501370
5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### gathering all the data of the current locations(food places) by making a get request in Forsquare

# %%
CLIENT_ID = 'BWMTUZQYGU4TI1TFRSQBF5CNBKKROSW1OTOE4YR31QYUMAL1' # your Foursquare ID
CLIENT_SECRET = 'E1GDUMA3AMSI1JSIPZKA5UJ11AIVNBC2VMQX2L3L5IFMFLCU' # your Foursquare Secret
ACCESS_TOKEN = 'F0DUIXZZ3JI5JZP3PDRE10QU3SZGMM2IYYVXNNHZ3WUXXYEX' # your FourSquare Access Token
VERSION = '20210406'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BWMTUZQYGU4TI1TFRSQBF5CNBKKROSW1OTOE4YR31QYUMAL1
# CLIENT_SECRET:E1GDUMA3AMSI1JSIPZKA5UJ11AIVNBC2VMQX2L3L5IFMFLCU

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, section="food"):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&section={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION,
            section,
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
berlin_venues = getNearbyVenues(names=df['Neighborhoods'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )

# %%
print(berlin_venues.shape)
berlin_venues.head()
# Out:
# (891, 7)
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Charlottenburg              52.515747               13.309683
# 1  Charlottenburg              52.515747               13.309683
# 2  Charlottenburg              52.515747               13.309683
# 3  Charlottenburg              52.515747               13.309683
# 4  Charlottenburg              52.515747               13.309683
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0       Trattoria Rathaus Piazza       52.516778        13.308748
# 1    Zur Mieze - Katzenmusikcafé       52.515899        13.304765
# 2     Sole d`Oro CUCINA ITALIANA       52.514660        13.305146
# 3               Curry Station 36       52.514946        13.315115
# 4  Falafel, Schawarma & Halloumi       52.512515        13.305099
#
#          Venue Category
# 0     Trattoria/Osteria
# 1              Pet Café
# 2           Pizza Place
# 3  Fast Food Restaurant
# 4    Falafel Restaurant

# %%
berlin_venues.groupby('Neighborhood').count()
# Out:
#                            Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
#  Grünau                                        4                       4
# Adlershof                                      7                       7
# Alt-Hohenschönhausen                           4                       4
# Alt-Treptow                                   17                      17
# Baumschulenweg                                 5                       5
# Biesdorf                                       5                       5
# Blankenburg                                    3                       3
# Blankenfelde                                   3                       3
# Bohnsdorf                                      2                       2
# Borsigwalde                                    4                       4
# Britz                                          4                       4
# Buch                                           6                       6
# Buckow                                         1                       1
# Charlottenburg                                32                      32
# Charlottenburg-Nord                            3                       3
# Dahlem                                         5                       5
# Falkenberg                                     1                       1
# Falkenhagener Feld                             3                       3
# Fennpfuhl                                      5                       5
# Französisch Buchholz                           2                       2
# Friedenau                                     14                      14
# Friedrichsfelde                                5                       5
# Friedrichshagen                               13                      13
# Friedrichshain                                28                      28
# Frohnau                                        6                       6
# Gatow                                          5                       5
# Gesundbrunnen                                 32                      32
# Gropiusstadt                                   6                       6
# Grunewald                                      7                       7
# Halensee                                      21                      21
# Hansaviertel                                  10                      10
# Haselhorst                                     5                       5
# Heinersdorf                                    4                       4
# Hellersdorf                                    6                       6
# Hermsdorf                                      5                       5
# Johannisthal                                   4                       4
# Karlshorst                                    19                      19
# Karow                                          3                       3
# Kaulsdorf                                      2                       2
# Kladow                                         1                       1
# Konradshöhe                                    3                       3
# Kreuzberg                                     36                      36
# Köpenick                                      10                      10
# Lankwitz                                       6                       6
# Lichtenberg                                    4                       4
# Lichtenrade                                    4                       4
# Lichterfelde                                   9                       9
# Lübars                                         2                       2
# Mahlsdorf                                      4                       4
# Malchow                                        3                       3
# Mariendorf                                    10                      10
# Marienfelde                                    4                       4
# Marzahn                                        3                       3
# Mitte                                         44                      44
# Moabit                                        42                      42
# Märkisches Viertel                             6                       6
# Müggelheim                                     6                       6
# Neu-Hohenschönhausen                           4                       4
# Neukölln                                      48                      48
# Niederschöneweide                              5                       5
# Niederschönhausen                              5                       5
# Nikolassee                                     2                       2
# Oberschöneweide                               15                      15
# Pankow                                         2                       2
# Plänterwald                                    5                       5
# Prenzlauer Berg                               26                      26
# Rosenthal                                      2                       2
# Rudow                                          4                       4
# Rummelsburg                                    8                       8
# Schmargendorf                                 14                      14
# Schmöckwitz                                    3                       3
# Schöneberg                                    30                      30
# Siemensstadt                                   4                       4
# Spandau                                       30                      30
# Staaken                                        2                       2
# Stadtrandsiedlung Malchow                      1                       1
# Steglitz                                      35                      35
# Tegel                                         31                      31
# Tempelhof                                     13                      13
# Tiergarten                                     4                       4
# Waidmannslust                                  4                       4
# Wannsee                                        4                       4
# Wartenberg                                     4                       4
# Wedding                                        4                       4
# Weißensee                                      6                       6
# Westend                                        4                       4
# Wilhelmsruh                                    5                       5
# Wilhelmstadt                                   4                       4
# Wilmersdorf                                   34                      34
# Wittenau                                       5                       5
# Zehlendorf                                    16                      16
#
#                            Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
#  Grünau                        4               4                4
# Adlershof                      7               7                7
# Alt-Hohenschönhausen           4               4                4
# Alt-Treptow                   17              17               17
# Baumschulenweg                 5               5                5
# Biesdorf                       5               5                5
# Blankenburg                    3               3                3
# Blankenfelde                   3               3                3
# Bohnsdorf                      2               2                2
# Borsigwalde                    4               4                4
# Britz                          4               4                4
# Buch                           6               6                6
# Buckow                         1               1                1
# Charlottenburg                32              32               32
# Charlottenburg-Nord            3               3                3
# Dahlem                         5               5                5
# Falkenberg                     1               1                1
# Falkenhagener Feld             3               3                3
# Fennpfuhl                      5               5                5
# Französisch Buchholz           2               2                2
# Friedenau                     14              14               14
# Friedrichsfelde                5               5                5
# Friedrichshagen               13              13               13
# Friedrichshain                28              28               28
# Frohnau                        6               6                6
# Gatow                          5               5                5
# Gesundbrunnen                 32              32               32
# Gropiusstadt                   6               6                6
# Grunewald                      7               7                7
# Halensee                      21              21               21
# Hansaviertel                  10              10               10
# Haselhorst                     5               5                5
# Heinersdorf                    4               4                4
# Hellersdorf                    6               6                6
# Hermsdorf                      5               5                5
# Johannisthal                   4               4                4
# Karlshorst                    19              19               19
# Karow                          3               3                3
# Kaulsdorf                      2               2                2
# Kladow                         1               1                1
# Konradshöhe                    3               3                3
# Kreuzberg                     36              36               36
# Köpenick                      10              10               10
# Lankwitz                       6               6                6
# Lichtenberg                    4               4                4
# Lichtenrade                    4               4                4
# Lichterfelde                   9               9                9
# Lübars                         2               2                2
# Mahlsdorf                      4               4                4
# Malchow                        3               3                3
# Mariendorf                    10              10               10
# Marienfelde                    4               4                4
# Marzahn                        3               3                3
# Mitte                         44              44               44
# Moabit                        42              42               42
# Märkisches Viertel             6               6                6
# Müggelheim                     6               6                6
# Neu-Hohenschönhausen           4               4                4
# Neukölln                      48              48               48
# Niederschöneweide              5               5                5
# Niederschönhausen              5               5                5
# Nikolassee                     2               2                2
# Oberschöneweide               15              15               15
# Pankow                         2               2                2
# Plänterwald                    5               5                5
# Prenzlauer Berg               26              26               26
# Rosenthal                      2               2                2
# Rudow                          4               4                4
# Rummelsburg                    8               8                8
# Schmargendorf                 14              14               14
# Schmöckwitz                    3               3                3
# Schöneberg                    30              30               30
# Siemensstadt                   4               4                4
# Spandau                       30              30               30
# Staaken                        2               2                2
# Stadtrandsiedlung Malchow      1               1                1
# Steglitz                      35              35               35
# Tegel                         31              31               31
# Tempelhof                     13              13               13
# Tiergarten                     4               4                4
# Waidmannslust                  4               4                4
# Wannsee                        4               4                4
# Wartenberg                     4               4                4
# Wedding                        4               4                4
# Weißensee                      6               6                6
# Westend                        4               4                4
# Wilhelmsruh                    5               5                5
# Wilhelmstadt                   4               4                4
# Wilmersdorf                   34              34               34
# Wittenau                       5               5                5
# Zehlendorf                    16              16               16
#
#                            Venue Category
# Neighborhood
#  Grünau                                 4
# Adlershof                               7
# Alt-Hohenschönhausen                    4
# Alt-Treptow                            17
# Baumschulenweg                          5
# Biesdorf                                5
# Blankenburg                             3
# Blankenfelde                            3
# Bohnsdorf                               2
# Borsigwalde                             4
# Britz                                   4
# Buch                                    6
# Buckow                                  1
# Charlottenburg                         32
# Charlottenburg-Nord                     3
# Dahlem                                  5
# Falkenberg                              1
# Falkenhagener Feld                      3
# Fennpfuhl                               5
# Französisch Buchholz                    2
# Friedenau                              14
# Friedrichsfelde                         5
# Friedrichshagen                        13
# Friedrichshain                         28
# Frohnau                                 6
# Gatow                                   5
# Gesundbrunnen                          32
# Gropiusstadt                            6
# Grunewald                               7
# Halensee                               21
# Hansaviertel                           10
# Haselhorst                              5
# Heinersdorf                             4
# Hellersdorf                             6
# Hermsdorf                               5
# Johannisthal                            4
# Karlshorst                             19
# Karow                                   3
# Kaulsdorf                               2
# Kladow                                  1
# Konradshöhe                             3
# Kreuzberg                              36
# Köpenick                               10
# Lankwitz                                6
# Lichtenberg                             4
# Lichtenrade                             4
# Lichterfelde                            9
# Lübars                                  2
# Mahlsdorf                               4
# Malchow                                 3
# Mariendorf                             10
# Marienfelde                             4
# Marzahn                                 3
# Mitte                                  44
# Moabit                                 42
# Märkisches Viertel                      6
# Müggelheim                              6
# Neu-Hohenschönhausen                    4
# Neukölln                               48
# Niederschöneweide                       5
# Niederschönhausen                       5
# Nikolassee                              2
# Oberschöneweide                        15
# Pankow                                  2
# Plänterwald                             5
# Prenzlauer Berg                        26
# Rosenthal                               2
# Rudow                                   4
# Rummelsburg                             8
# Schmargendorf                          14
# Schmöckwitz                             3
# Schöneberg                             30
# Siemensstadt                            4
# Spandau                                30
# Staaken                                 2
# Stadtrandsiedlung Malchow               1
# Steglitz                               35
# Tegel                                  31
# Tempelhof                              13
# Tiergarten                              4
# Waidmannslust                           4
# Wannsee                                 4
# Wartenberg                              4
# Wedding                                 4
# Weißensee                               6
# Westend                                 4
# Wilhelmsruh                             5
# Wilhelmstadt                            4
# Wilmersdorf                            34
# Wittenau                                5
# Zehlendorf                             16
